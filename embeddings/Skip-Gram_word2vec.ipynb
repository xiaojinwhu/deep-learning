# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
threshold = 1e-5
word_counts = Counter(int_words)
#print(word_counts)
total_count = len(int_words)
print(total_count)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [ word for word in int_words if random.random()<(1-p_drop[word])]
#train_words = # The final subsampled word list
# Out:
# 16680599

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx]+words[idx+1:stop+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1,1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed,n_sampled,n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6612 0.3686 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6232 0.3631 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5158 0.3625 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5992 0.3622 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5214 0.3609 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5588 0.3598 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5638 0.3620 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5368 0.3637 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4603 0.3643 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4039 0.3642 sec/batch
# Nearest to new: augustan, rhodium, racists, viscosity, endings, flakes, quantity, min,
# Nearest to have: ligand, illogical, decentralized, ungainly, callisthenes, profit, amigabasic, certification,
# Nearest to two: string, forcefully, elegantly, materially, metropolis, emptiness, daisy, deformities,
# Nearest to th: dhamma, jeb, outbreaks, estonians, frenetic, teapot, onward, empiricism,
# Nearest to years: montane, took, anxiolytic, riff, narrated, clipped, orientational, imprint,
# Nearest to some: isabelle, corresponding, belgium, nika, maya, noncombatant, palimpsest, tor,
# Nearest to however: theirs, thirtieth, accounted, ceases, accelerated, subdivide, thalassemia, ciliates,
# Nearest to when: motherhood, chime, nther, issas, vesalius, horseshoes, uf, conlang,
# Nearest to creation: brattle, disfavor, tuareg, heresiologists, turco, darlington, picking, landis,
# Nearest to shows: lehigh, agonist, avert, brochure, openvms, existentialist, infidelity, refusal,
# Nearest to derived: pus, verdict, accusation, ephraem, production, intoxicated, integrity, coordinate,
# Nearest to issue: outdoors, karl, koktebel, durr, maxine, phrased, larsen, jong,
# Nearest to scale: expresses, placenta, solstice, klamath, defection, dentists, throughout, ellipses,
# Nearest to experience: ascended, supergroup, yag, fencing, laine, mezzo, patriot, suspends,
# Nearest to applications: perineum, infringes, miscarriages, taur, duhem, dani, undeserved, keynesians,
# Nearest to joseph: rollercoaster, samyaksam, consonance, mizoguchi, mutual, blessing, dimers, pounds,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4990 0.3705 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3836 0.3675 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3122 0.3722 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.1996 0.3795 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1436 0.4392 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1500 0.4536 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0787 0.4551 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0367 0.4337 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0036 0.4179 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9470 0.4279 sec/batch
# Nearest to new: quantity, but, augustan, unique, invasion, viscosity, min, concentrated,
# Nearest to have: though, decentralized, ligand, illogical, deep, referendum, as, appears,
# Nearest to two: forcefully, even, metropolis, daisy, pyrenees, string, compromise, wider,
# Nearest to th: onward, outbreaks, dhamma, prosecution, empiricism, standing, jeb, teapot,
# Nearest to years: montane, took, imprint, eight, pertains, nevertheless, giving, stops,
# Nearest to some: corresponding, isabelle, authority, belgium, derived, tor, chance, edition,
# Nearest to however: theirs, single, ceases, accelerated, accounted, subdivide, functional, thirtieth,
# Nearest to when: motherhood, nation, craft, saturday, issas, chime, abdication, lachaise,
# Nearest to creation: picking, disfavor, tuareg, brattle, generation, aware, had, monsters,
# Nearest to shows: lehigh, essentially, agonist, antarctica, pancake, avert, other, killing,
# Nearest to derived: coordinate, production, consider, verdict, integrity, some, accusation, pus,
# Nearest to issue: karl, outdoors, durr, expected, koktebel, phrased, novell, ballpark,
# Nearest to scale: throughout, expresses, solstice, placenta, defection, edward, transmitted, compilation,
# Nearest to experience: ascended, piece, fencing, supergroup, refers, yag, periods, laine,
# Nearest to applications: miscarriages, transferred, strikes, intense, perineum, infringes, dani, doorway,
# Nearest to joseph: mutual, rollercoaster, pounds, samyaksam, consonance, zones, interruption, blessing,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9510 0.4504 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9177 0.4531 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8926 0.4442 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8621 0.4443 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8004 0.4645 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8312 0.4255 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8048 0.4789 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7775 0.5518 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8075 0.5511 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7731 0.5528 sec/batch
# Nearest to new: augustan, quantity, endings, elevating, honor, min, rhodium, viscosity,
# Nearest to have: decentralized, though, deep, ligand, illogical, labels, referendum, profit,
# Nearest to two: forcefully, pyrenees, metropolis, colspan, eulogy, almanac, compromise, censored,
# Nearest to th: onward, empiricism, outbreaks, jeb, dhamma, prosecution, teapot, believed,
# Nearest to years: montane, took, narrated, imprint, riff, eight, insurgency, nevertheless,
# Nearest to some: isabelle, corresponding, ours, painted, authority, nika, derived, palimpsest,
# Nearest to however: accelerated, theirs, ceases, thirtieth, single, functional, accounted, amounted,
# Nearest to when: motherhood, chime, abdication, attracting, horseshoes, craft, issas, nther,
# Nearest to creation: disfavor, pope, brattle, staking, darlington, tuareg, picking, heresiologists,
# Nearest to shows: lehigh, agonist, essentially, antarctica, other, avert, pancake, refusal,
# Nearest to derived: production, consider, coordinate, verdict, integrity, accusation, pus, intoxicated,
# Nearest to issue: karl, outdoors, maxine, ballpark, durr, jong, phrased, styles,
# Nearest to scale: placenta, solstice, throughout, expresses, edward, transmitted, phenomena, defection,
# Nearest to experience: ascended, fencing, piece, supergroup, yag, keyboard, refers, strived,
# Nearest to applications: perineum, miscarriages, strikes, desk, transferred, duhem, contribute, intense,
# Nearest to joseph: mutual, consonance, samyaksam, drake, zones, pounds, blessing, rollercoaster,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7833 0.5484 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7658 0.5376 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7140 0.5377 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6894 0.4835 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7347 0.4727 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6881 0.4882 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7180 0.4747 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7298 0.4745 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7200 0.4780 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6374 0.4775 sec/batch
# Nearest to new: augustan, endings, elevating, honor, min, surfing, rhodium, gaussian,
# Nearest to have: though, decentralized, illogical, deep, ligand, labels, certification, ungainly,
# Nearest to two: forcefully, colspan, pyrenees, five, eulogy, metropolis, three, brighton,
# Nearest to th: onward, jeb, dhamma, empiricism, teapot, reuben, starr, bloodline,
# Nearest to years: narrated, montane, took, eight, riff, imprint, hern, greatest,
# Nearest to some: isabelle, ours, corresponding, nika, palimpsest, painted, classed, derived,
# Nearest to however: accelerated, thirtieth, ceases, theirs, barracks, amounted, hamper, change,
# Nearest to when: motherhood, chime, attracting, abdication, issas, uf, ligature, horseshoes,
# Nearest to creation: brattle, darlington, disfavor, tuareg, heresiologists, staking, traverse, pope,
# Nearest to shows: lehigh, agonist, avert, infidelity, proficiency, essentially, other, vanuatu,
# Nearest to derived: verdict, consider, production, accusation, coordinate, integrity, intoxicated, pus,
# Nearest to issue: karl, outdoors, maxine, larsen, refusing, durr, appalachia, jong,
# Nearest to scale: placenta, solstice, expresses, throughout, klamath, defection, phenomena, latins,
# Nearest to experience: ascended, fencing, supergroup, piece, yag, mezzo, anarchist, strived,
# Nearest to applications: perineum, undeserved, miscarriages, infringes, keynesians, ported, harden, contribute,
# Nearest to joseph: poet, samyaksam, consonance, dyer, drake, mutual, relativist, blessing,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6769 0.4777 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6700 0.4687 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6185 0.4739 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6253 0.4927 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6420 0.4765 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6034 0.4978 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6072 0.3369 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5392 0.5011 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5151 0.5137 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5221 0.4587 sec/batch
# Nearest to new: augustan, elevating, surfing, endings, honor, rhodium, flawlessly, implored,
# Nearest to have: though, decentralized, deep, illogical, ungainly, callisthenes, certification, labels,
# Nearest to two: five, four, forcefully, three, colspan, zero, nine, eulogy,
# Nearest to th: onward, jeb, dhamma, teapot, bloodline, reuben, empiricism, starr,
# Nearest to years: montane, narrated, riff, hern, took, imprint, eight, vong,
# Nearest to some: isabelle, corresponding, ours, nika, palimpsest, noncombatant, derived, colonialism,
# Nearest to however: accelerated, thirtieth, barracks, subsidence, ceases, theirs, change, subdivide,
# Nearest to when: motherhood, chime, attracting, uf, horseshoes, abdication, brosnan, ligature,
# Nearest to creation: darlington, tuareg, brattle, disfavor, heresiologists, branding, staking, traverse,
# Nearest to shows: agonist, lehigh, chattahoochee, avert, infidelity, observatories, phages, proficiency,
# Nearest to derived: consider, coordinate, verdict, pus, production, accusation, integrity, expectancies,
# Nearest to issue: maxine, karl, outdoors, appalachia, refusing, durr, crowds, larsen,
# Nearest to scale: placenta, phenomena, klamath, water, defection, expresses, spartacist, latins,
# Nearest to experience: ascended, piece, fencing, strived, supergroup, yag, derisively, mezzo,
# Nearest to applications: perineum, undeserved, ported, typology, miscarriages, keynesians, harden, infrastructure,
# Nearest to joseph: poet, samyaksam, consonance, drake, peter, dyer, relativist, mizoguchi,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5024 0.4312 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5037 0.4165 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4439 0.4173 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5107 0.4095 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5120 0.4075 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4839 0.4166 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4569 0.4827 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4015 0.4249 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4384 0.4512 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4263 0.4219 sec/batch
# Nearest to new: augustan, surfing, elevating, honor, ushant, flawlessly, bulletins, rhodium,
# Nearest to have: though, decentralized, callisthenes, illogical, ungainly, deep, certification, envisage,
# Nearest to two: five, three, zero, four, brighton, forcefully, colspan, pyrenees,
# Nearest to th: onward, dhamma, teapot, jeb, reuben, bloodline, posthumously, starr,
# Nearest to years: narrated, montane, hern, riff, took, vong, eight, imprint,
# Nearest to some: corresponding, ours, derived, nika, isabelle, grasp, palimpsest, noncombatant,
# Nearest to however: subsidence, thirtieth, accelerated, theirs, barracks, amounted, change, ceases,
# Nearest to when: chime, motherhood, attracting, judgment, abdication, horseshoes, brosnan, naumburg,
# Nearest to creation: darlington, brattle, tuareg, branding, disfavor, heresiologists, traverse, staking,
# Nearest to shows: agonist, lehigh, chattahoochee, avert, infidelity, observatories, existentialist, phages,
# Nearest to derived: consider, coordinate, production, some, accusation, pus, expectancies, verdict,
# Nearest to issue: maxine, karl, outdoors, appalachia, refusing, phrased, durr, crowds,
# Nearest to scale: placenta, water, phenomena, spartacist, klamath, defection, solstice, ellipses,
# Nearest to experience: ascended, supergroup, piece, strived, refers, tata, fencing, assertion,
# Nearest to applications: perineum, ported, undeserved, typology, keynesians, cnc, harden, miscarriages,
# Nearest to joseph: poet, blessing, samyaksam, drake, consonance, relativist, peter, gaule,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4390 0.4202 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4038 0.4145 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4532 0.4164 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4056 0.4364 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4298 0.4343 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4485 0.4155 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3570 0.4193 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3505 0.4474 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4008 0.4307 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3728 0.4011 sec/batch
# Nearest to new: surfing, augustan, ushant, elevating, honor, flawlessly, chartered, bulletins,
# Nearest to have: though, decentralized, callisthenes, deep, illogical, envisage, fallacies, certification,
# Nearest to two: five, three, zero, four, brighton, nine, seven, forcefully,
# Nearest to th: onward, teapot, dhamma, bloodline, reuben, inscriptions, akhenaten, skydiving,
# Nearest to years: narrated, hern, montane, vong, infant, riff, eight, hundred,
# Nearest to some: ours, corresponding, nika, derived, palimpsest, grasp, efficacy, refer,
# Nearest to however: subsidence, barracks, ceases, accelerated, theirs, change, achieved, ciliates,
# Nearest to when: chime, attracting, motherhood, judgment, naumburg, to, brosnan, horseshoes,
# Nearest to creation: darlington, branding, brattle, tuareg, heresiologists, concepts, disfavor, thinkers,
# Nearest to shows: agonist, chattahoochee, infidelity, lehigh, avert, observatories, other, grey,
# Nearest to derived: coordinate, consider, production, expectancies, pus, some, accusation, verdict,
# Nearest to issue: maxine, refusing, appalachia, karl, outdoors, larsen, phrased, durr,
# Nearest to scale: placenta, water, spartacist, klamath, latins, solstice, ellipses, expresses,
# Nearest to experience: ascended, strived, fundamentally, refers, piece, weh, supergroup, assertion,
# Nearest to applications: perineum, ported, cnc, undeserved, operate, typology, millimeter, keynesians,
# Nearest to joseph: poet, blessing, gaule, samyaksam, peter, duce, relativist, consonance,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3711 0.3771 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3986 0.3727 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3534 0.3781 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3559 0.3910 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4025 0.3845 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3652 0.3890 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3917 0.3847 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3747 0.3915 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3252 0.3916 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3375 0.3885 sec/batch
# Nearest to new: surfing, augustan, hebrides, bulletins, ushant, marzipan, bhakti, baggins,
# Nearest to have: though, decentralized, callisthenes, deep, envisage, illogical, dignified, fallacies,
# Nearest to two: five, three, zero, four, seven, nine, six, brighton,
# Nearest to th: onward, inscriptions, dhamma, italy, teapot, bloodline, believed, skydiving,
# Nearest to years: vong, hern, infant, narrated, eight, montane, hundred, population,
# Nearest to some: corresponding, ours, derived, nika, grasp, palimpsest, efficacy, derivations,
# Nearest to however: subsidence, theirs, accelerated, change, ceases, barracks, resolving, ciliates,
# Nearest to when: chime, attracting, motherhood, brosnan, to, judgment, labia, horseshoes,
# Nearest to creation: darlington, branding, had, heresiologists, thinkers, tuareg, concepts, disfavor,
# Nearest to shows: agonist, infidelity, chattahoochee, observatories, lehigh, existentialist, avert, grey,
# Nearest to derived: coordinate, expectancies, production, arabic, pus, some, consider, refer,
# Nearest to issue: maxine, refusing, appalachia, karl, phrased, polyrhythmic, outdoors, foreshadowed,
# Nearest to scale: placenta, water, spartacist, klamath, accessible, solstice, transmitted, acuity,
# Nearest to experience: ascended, supergroup, fundamentally, strived, dwells, assertion, weh, piece,
# Nearest to applications: perineum, ported, desk, cnc, keynesians, millimeter, task, undeserved,
# Nearest to joseph: poet, blessing, gaule, samyaksam, peter, duce, relativist, consonance,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3472 0.4016 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2855 0.4007 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3660 0.4158 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3793 0.4362 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3622 0.4021 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2959 0.4125 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3037 0.4228 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3494 0.4240 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2258 0.3667 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2985 0.3644 sec/batch
# Nearest to new: surfing, augustan, hebrides, ushant, marzipan, newspaper, dandridge, flawlessly,
# Nearest to have: decentralized, though, illogical, callisthenes, envisage, ungainly, fallacies, hypnotism,
# Nearest to two: five, zero, four, three, nine, seven, one, six,
# Nearest to th: onward, teapot, inscriptions, akhenaten, italy, bloodline, dhamma, germanic,
# Nearest to years: vong, infant, hern, population, live, montane, year, eight,
# Nearest to some: corresponding, ours, derived, nika, isabelle, efficacy, palimpsest, tone,
# Nearest to however: subsidence, theirs, accelerated, resolving, barracks, thirtieth, ciliates, hamper,
# Nearest to when: chime, attracting, brosnan, teos, judgment, abdication, motherhood, labia,
# Nearest to creation: darlington, branding, heresiologists, thinkers, brattle, concepts, tuareg, disfavor,
# Nearest to shows: infidelity, agonist, chattahoochee, observatories, lehigh, mythic, sle, existentialist,
# Nearest to derived: arabic, expectancies, pus, coordinate, refer, some, consider, production,
# Nearest to issue: refusing, maxine, appalachia, karl, phrased, polyrhythmic, commissioners, foreshadowed,
# Nearest to scale: placenta, water, klamath, accessible, spartacist, acuity, transmitted, ellipses,
# Nearest to experience: ascended, supergroup, fundamentally, dwells, weh, refers, assertion, piece,
# Nearest to applications: perineum, ported, desk, cnc, keynesians, undeserved, task, millimeter,
# Nearest to joseph: poet, blessing, duce, gaule, samyaksam, dorset, relativist, peter,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3147 0.3724 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2949 0.4028 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3141 0.1810 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2447 0.3896 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2421 0.3876 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2286 0.4326 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2372 0.4217 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2110 0.4100 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2425 0.4151 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1741 0.4305 sec/batch
# Nearest to new: surfing, chartered, augustan, marzipan, hebrides, ushant, flawlessly, bulletins,
# Nearest to have: decentralized, though, callisthenes, envisage, illogical, deep, ungainly, fallacies,
# Nearest to two: five, three, zero, four, nine, seven, one, six,
# Nearest to th: onward, teapot, inscriptions, akhenaten, italy, germanic, bloodline, guerrillas,
# Nearest to years: vong, infant, hern, year, live, eight, montane, population,
# Nearest to some: ours, efficacy, corresponding, nika, isabelle, grasp, derived, chance,
# Nearest to however: theirs, subsidence, accelerated, resolving, barracks, thirtieth, amounted, hamper,
# Nearest to when: chime, brosnan, labia, teos, judgment, attracting, motherhood, abdication,
# Nearest to creation: darlington, concepts, branding, brattle, thinkers, heresiologists, confucianist, translator,
# Nearest to shows: infidelity, agonist, lehigh, chattahoochee, observatories, mythic, sle, grey,
# Nearest to derived: arabic, expectancies, pus, refer, etymology, coordinate, production, some,
# Nearest to issue: refusing, maxine, appalachia, karl, phrased, polyrhythmic, yitzhak, foreshadowed,
# Nearest to scale: placenta, solstice, ellipses, klamath, acuity, water, accessible, spartacist,
# Nearest to experience: ascended, supergroup, fundamentally, weh, perjury, assertion, dwells, life,
# Nearest to applications: ported, perineum, desk, cnc, keynesians, task, millimeter, undeserved,
# Nearest to joseph: poet, blessing, gaule, duce, relativist, dorset, samyaksam, consonance,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2630 0.4253 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2265 0.4244 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2200 0.4267 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1442 0.4175 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1688 0.4503 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1806 0.4263 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1756 0.3950 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1917 0.3883 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2057 0.3904 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1767 0.3854 sec/batch
# Nearest to new: chartered, surfing, ushant, newspaper, marzipan, flawlessly, dandridge, cbc,
# Nearest to have: callisthenes, decentralized, envisage, though, illogical, fallacies, dignified, chin,
# Nearest to two: five, three, four, zero, nine, seven, one, six,
# Nearest to th: onward, teapot, inscriptions, guerrillas, akhenaten, bloodline, dhamma, czechs,
# Nearest to years: vong, infant, zero, eight, year, hern, four, live,
# Nearest to some: efficacy, ours, nika, corresponding, isabelle, derived, grasp, tone,
# Nearest to however: theirs, accelerated, resolving, subsidence, thirtieth, barracks, amounted, hamper,
# Nearest to when: chime, brosnan, labia, to, judgment, pass, teos, it,
# Nearest to creation: darlington, concepts, thinkers, branding, confucianist, christian, translator, preached,
# Nearest to shows: infidelity, agonist, observatories, grey, mythic, chattahoochee, sle, travelogue,
# Nearest to derived: arabic, expectancies, some, pus, etymology, refer, production, consider,
# Nearest to issue: refusing, maxine, appalachia, karl, polyrhythmic, regulated, crick, phrased,
# Nearest to scale: solstice, placenta, ellipses, accessible, klamath, acuity, water, spartacist,
# Nearest to experience: ascended, fundamentally, dwells, supergroup, perjury, assertion, neuroscience, weh,
# Nearest to applications: perineum, ported, task, desk, cnc, keynesians, deanna, operate,
# Nearest to joseph: poet, blessing, duce, gaule, relativist, samyaksam, peter, consonance,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1671 0.4169 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2010 0.4380 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1851 0.3906 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1786 0.3858 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1986 0.4107 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2172 0.4036 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1978 0.4203 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1507 0.4131 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1621 0.3994 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1912 0.4001 sec/batch
# Nearest to new: chartered, surfing, newspaper, york, hobbyists, flawlessly, marzipan, fruition,
# Nearest to have: callisthenes, decentralized, though, fallacies, envisage, dignified, illogical, sayings,
# Nearest to two: four, zero, three, five, nine, seven, one, six,
# Nearest to th: onward, teapot, inscriptions, guerrillas, italy, akhenaten, dhamma, germanic,
# Nearest to years: vong, infant, year, zero, eight, four, population, live,
# Nearest to some: isabelle, nika, ours, efficacy, corresponding, taganrog, derived, tone,
# Nearest to however: accelerated, theirs, subsidence, resolving, single, hamper, barracks, dimples,
# Nearest to when: chime, teos, brosnan, attracting, labia, horseshoes, pass, to,
# Nearest to creation: darlington, concepts, branding, thinkers, translator, confucianist, spinoza, heresiologists,
# Nearest to shows: infidelity, agonist, chattahoochee, tab, sle, observatories, mythic, whistle,
# Nearest to derived: arabic, expectancies, pus, etymology, production, refer, some, nonterminal,
# Nearest to issue: refusing, karl, appalachia, maxine, crick, phrased, yitzhak, polyrhythmic,
# Nearest to scale: solstice, placenta, ellipses, water, acuity, accessible, phenomena, translational,
# Nearest to experience: ascended, neuroscience, dwells, fundamentally, assertion, reality, supergroup, weh,
# Nearest to applications: perineum, keynesians, ported, desk, cnc, millimeter, task, floppies,
# Nearest to joseph: poet, duce, gaule, blessing, boyle, relativist, leonid, peter,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2306 0.3934 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1792 0.4050 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1888 0.4294 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1752 0.4294 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1173 0.3864 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1183 0.4009 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1783 0.4154 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1360 0.3900 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1885 0.4100 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2370 0.4200 sec/batch
# Nearest to new: chartered, surfing, york, oxford, newspaper, dandridge, cbc, press,
# Nearest to have: callisthenes, decentralized, though, fallacies, sayings, envisage, dignified, illogical,
# Nearest to two: four, three, zero, five, nine, seven, one, six,
# Nearest to th: onward, inscriptions, teapot, early, germanic, sourcebook, dhamma, wartburg,
# Nearest to years: vong, zero, year, infant, eight, hern, four, population,
# Nearest to some: isabelle, nika, belgium, taganrog, ours, efficacy, corresponding, derived,
# Nearest to however: accelerated, barracks, theirs, fugitives, subsidence, tetum, resolving, amounted,
# Nearest to when: chime, teos, abdication, brosnan, pass, labia, horseshoes, attracting,
# Nearest to creation: darlington, concepts, branding, maintains, translator, despotism, heresiologists, spinoza,
# Nearest to shows: infidelity, hoffman, tab, mythic, chattahoochee, agonist, whistle, grey,
# Nearest to derived: arabic, expectancies, etymology, pus, alphabets, production, suffix, refer,
# Nearest to issue: refusing, appalachia, karl, maxine, required, abdallah, foreshadowed, before,
# Nearest to scale: solstice, placenta, ellipses, accessible, acuity, water, phenomena, klamath,
# Nearest to experience: ascended, neuroscience, supergroup, dwells, cartoonists, reality, derisively, perjury,
# Nearest to applications: desk, keynesians, perineum, cnc, ported, millimeter, task, deanna,
# Nearest to joseph: poet, gaule, duce, blessing, boyle, relativist, johann, leonid,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2282 0.4062 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1454 0.3870 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1477 0.3951 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1585 0.4077 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0424 0.4194 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1312 0.4114 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1451 0.3968 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1442 0.4245 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1677 0.0673 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1470 0.4270 sec/batch
# Nearest to new: chartered, surfing, york, marzipan, hebrides, oxford, newspaper, dandridge,
# Nearest to have: callisthenes, decentralized, though, envisage, fallacies, sayings, illogical, dignified,
# Nearest to two: four, zero, three, five, one, nine, seven, six,
# Nearest to th: onward, teapot, inscriptions, early, transl, frenetic, guerrillas, dhamma,
# Nearest to years: vong, zero, year, infant, eight, four, hern, mortality,
# Nearest to some: isabelle, ours, nika, efficacy, taganrog, belgium, tone, palimpsest,
# Nearest to however: accelerated, theirs, barracks, subsidence, territory, fugitives, accounted, menorah,
# Nearest to when: chime, pass, abdication, brosnan, teos, labia, horseshoes, it,
# Nearest to creation: darlington, concepts, maintains, translator, branding, directory, spinoza, lis,
# Nearest to shows: infidelity, tab, hoffman, chattahoochee, agonist, clockwise, sle, graph,
# Nearest to derived: arabic, etymology, expectancies, pus, production, nonterminal, alphabets, suffix,
# Nearest to issue: refusing, karl, appalachia, maxine, plies, foreshadowed, crick, abdallah,
# Nearest to scale: solstice, ellipses, accessible, acuity, placenta, nanotechnology, phenomena, water,
# Nearest to experience: ascended, neuroscience, derisively, fundamentally, reality, supergroup, weh, psychedelic,
# Nearest to applications: desk, cnc, perineum, keynesians, ported, task, lapsed, millimeter,
# Nearest to joseph: poet, gaule, blessing, duce, boyle, johann, dorset, relativist,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0830 0.4446 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0781 0.4402 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0843 0.4326 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0641 0.4330 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0964 0.4363 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0403 0.3899 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1025 0.3948 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0983 0.4160 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1013 0.3722 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0340 0.3760 sec/batch
# Nearest to new: chartered, york, surfing, wayland, oxford, newspaper, hebrides, completed,
# Nearest to have: callisthenes, though, decentralized, envisage, fallacies, chin, illogical, sayings,
# Nearest to two: four, three, zero, five, nine, seven, one, six,
# Nearest to th: onward, teapot, inscriptions, early, guerrillas, transl, afc, graphemes,
# Nearest to years: vong, zero, year, eight, four, infant, hern, age,
# Nearest to some: isabelle, efficacy, ours, nika, grasp, tone, mimic, taganrog,
# Nearest to however: accelerated, territory, theirs, subsidence, hamper, maneuvered, barracks, single,
# Nearest to when: chime, pass, brosnan, labia, to, abdication, horseshoes, teos,
# Nearest to creation: darlington, concepts, translator, spinoza, maintains, branding, foibles, thinkers,
# Nearest to shows: infidelity, hoffman, tab, clockwise, graph, sle, chattahoochee, agonist,
# Nearest to derived: arabic, etymology, expectancies, pus, monmouth, family, suffix, ptb,
# Nearest to issue: karl, refusing, appalachia, maxine, crick, plies, foreshadowed, abdallah,
# Nearest to scale: ellipses, accessible, solstice, acuity, phenomena, placenta, nanotechnology, numbering,
# Nearest to experience: ascended, neuroscience, reality, life, derisively, dwells, pinball, weh,
# Nearest to applications: cnc, desk, perineum, ported, keynesians, task, millimeter, floppies,
# Nearest to joseph: duce, blessing, gaule, poet, boyle, consonance, relativist, rollercoaster,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0230 0.3784 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0198 0.3761 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0320 0.3671 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0826 0.3700 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0647 0.3725 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0899 0.3726 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0471 0.4168 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1180 0.3992 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0563 0.3747 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0399 0.3666 sec/batch
# Nearest to new: chartered, york, surfing, oxford, cbc, wayland, completed, expositions,
# Nearest to have: callisthenes, though, decentralized, envisage, fallacies, chin, has, dignified,
# Nearest to two: three, four, zero, five, nine, one, six, seven,
# Nearest to th: onward, early, teapot, guerrillas, transl, inscriptions, afc, dhamma,
# Nearest to years: zero, vong, four, eight, year, infant, age, two,
# Nearest to some: isabelle, ours, efficacy, nika, grasp, tone, licence, mimic,
# Nearest to however: accelerated, territory, tetum, theirs, relegated, single, hamper, tariff,
# Nearest to when: chime, pass, brosnan, horseshoes, to, it, labia, inappropriately,
# Nearest to creation: darlington, concepts, translator, confucianist, spinoza, christian, maintains, despotism,
# Nearest to shows: infidelity, hoffman, tab, clockwise, graph, sle, agonist, vanuatu,
# Nearest to derived: arabic, etymology, expectancies, production, family, pus, ptb, monmouth,
# Nearest to issue: karl, refusing, appalachia, plies, crick, durr, novell, maxine,
# Nearest to scale: solstice, ellipses, accessible, nanotechnology, acuity, phenomena, sufficiently, translational,
# Nearest to experience: ascended, neuroscience, reality, derisively, perjury, proverb, pinball, strived,
# Nearest to applications: cnc, task, keynesians, desk, perineum, ported, lapsed, deanna,
# Nearest to joseph: duce, boyle, gaule, poet, blessing, peter, leonid, relativist,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0395 0.3805 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0873 0.3732 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0576 0.3867 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0757 0.3679 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0673 0.3658 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0494 0.3705 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0682 0.3641 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0830 0.3687 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1132 0.3667 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0578 0.3692 sec/batch
# Nearest to new: chartered, york, surfing, hebrides, oxford, completed, wayland, affiliated,
# Nearest to have: callisthenes, though, fallacies, dignified, decentralized, sayings, sonia, prophesying,
# Nearest to two: four, three, zero, five, nine, one, six, seven,
# Nearest to th: onward, early, speyer, graphemes, six, dhamma, inscriptions, transl,
# Nearest to years: vong, zero, eight, year, four, infant, population, hern,
# Nearest to some: isabelle, ours, tone, nika, taganrog, palimpsest, grasp, efficacy,
# Nearest to however: territory, accelerated, theirs, tetum, relegated, barracks, single, hamper,
# Nearest to when: chime, abdication, to, brosnan, teos, labia, inappropriately, horseshoes,
# Nearest to creation: darlington, concepts, spinoza, rentals, branding, despotism, translator, discontinued,
# Nearest to shows: infidelity, tab, hoffman, clockwise, graph, vanuatu, avengers, rein,
# Nearest to derived: arabic, etymology, production, expectancies, suffix, pus, ptb, family,
# Nearest to issue: karl, refusing, appalachia, crick, jong, plies, millenarianism, foreshadowed,
# Nearest to scale: solstice, accessible, ellipses, acuity, phenomena, nanotechnology, placenta, diversifying,
# Nearest to experience: ascended, neuroscience, reality, pinball, derisively, proverb, strived, perjury,
# Nearest to applications: cnc, keynesians, deanna, desk, lapsed, task, perineum, millimeter,
# Nearest to joseph: boyle, gaule, duce, blessing, poet, peter, leonid, johann,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0732 0.3733 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0242 0.3693 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0312 0.3704 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0651 0.3730 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0673 0.3701 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1221 0.3880 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1365 0.4098 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0566 0.3650 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0409 0.3652 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0717 0.3632 sec/batch
# Nearest to new: york, chartered, hebrides, surfing, oxford, completed, expositions, ushant,
# Nearest to have: though, callisthenes, fallacies, sayings, envisage, decentralized, sonia, dignified,
# Nearest to two: four, three, zero, five, one, nine, seven, six,
# Nearest to th: onward, early, graphemes, teapot, speyer, transl, markkaa, dhamma,
# Nearest to years: zero, vong, eight, year, infant, four, mortality, fertility,
# Nearest to some: isabelle, tone, nika, taganrog, ours, shudo, palimpsest, yalu,
# Nearest to however: accelerated, territory, theirs, tetum, relegated, farms, hamper, barracks,
# Nearest to when: chime, brosnan, abdication, teos, to, inappropriately, it, labia,
# Nearest to creation: darlington, maintains, rentals, concepts, discontinued, spinoza, branding, ninja,
# Nearest to shows: infidelity, tab, graph, clockwise, hoffman, vanuatu, agonist, mythic,
# Nearest to derived: production, arabic, etymology, expectancies, monmouth, family, ptb, suffix,
# Nearest to issue: karl, refusing, appalachia, jong, crick, abdallah, novell, maxine,
# Nearest to scale: ellipses, solstice, accessible, nanotechnology, acuity, placenta, phenomena, numbering,
# Nearest to experience: ascended, derisively, pinball, reality, neuroscience, strived, psychedelic, proverb,
# Nearest to applications: desk, keynesians, cnc, ported, task, deanna, lapsed, perineum,
# Nearest to joseph: boyle, duce, gaule, leonid, blessing, peter, poet, relativist,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9814 0.3720 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0438 0.3679 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0460 0.3867 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0525 0.4259 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0740 0.4205 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0408 0.3641 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0076 0.4003 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0268 0.4344 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0305 0.4669 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9768 0.4136 sec/batch
# Nearest to new: york, chartered, surfing, hebrides, completed, mandinka, cbc, removed,
# Nearest to have: though, callisthenes, sayings, fallacies, decentralized, envisage, sonia, markan,
# Nearest to two: four, three, zero, five, one, nine, seven, six,
# Nearest to th: onward, early, rd, graphemes, remaining, afc, teapot, markkaa,
# Nearest to years: vong, year, zero, infant, eight, fertility, mortality, four,
# Nearest to some: isabelle, tone, shudo, ours, noncombatant, nika, grasp, taganrog,
# Nearest to however: accelerated, theirs, territory, relegated, single, tetum, farms, hamper,
# Nearest to when: abdication, chime, brosnan, inappropriately, to, teos, it, labia,
# Nearest to creation: darlington, rentals, concepts, ninja, maintains, foibles, discontinued, spinoza,
# Nearest to shows: infidelity, tab, hoffman, vanuatu, graph, clockwise, rein, sle,
# Nearest to derived: expectancies, production, etymology, arabic, nonterminal, monmouth, name, hanafi,
# Nearest to issue: karl, refusing, appalachia, plies, jong, crick, durr, maxine,
# Nearest to scale: ellipses, solstice, accessible, acuity, nanotechnology, phenomena, intuitive, timaeus,
# Nearest to experience: ascended, pinball, derisively, neuroscience, life, strived, psychedelic, reality,
# Nearest to applications: ported, desk, cnc, keynesians, task, lapsed, deanna, dani,
# Nearest to joseph: duce, boyle, gaule, poet, peter, blessing, leonid, consonance,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0062 0.4083 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9617 0.4081 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0238 0.3948 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0485 0.4085 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9994 0.3760 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9938 0.3845 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9238 0.4034 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9416 0.4096 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9452 0.3953 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9740 0.4206 sec/batch
# Nearest to new: york, chartered, surfing, hebrides, completed, oxford, wayland, mandinka,
# Nearest to have: though, callisthenes, sayings, fallacies, decentralized, there, envisage, chin,
# Nearest to two: four, three, zero, five, one, nine, seven, six,
# Nearest to th: onward, early, graphemes, afc, markkaa, rd, transl, teapot,
# Nearest to years: year, zero, vong, eight, four, infant, fertility, age,
# Nearest to some: isabelle, shudo, nika, tone, efficacy, lorry, licence, noncombatant,
# Nearest to however: accelerated, theirs, relegated, territory, tetum, single, farms, maneuvered,
# Nearest to when: to, labia, it, brosnan, chime, inappropriately, abdication, horseshoes,
# Nearest to creation: darlington, concepts, ninja, rentals, christian, spinoza, despotism, maintains,
# Nearest to shows: infidelity, tab, vanuatu, hoffman, rein, graph, muttiah, travelogue,
# Nearest to derived: production, expectancies, etymology, arabic, family, hanafi, name, nonterminal,
# Nearest to issue: karl, refusing, appalachia, crick, durr, sdf, novell, jong,
# Nearest to scale: ellipses, accessible, solstice, nanotechnology, intuitive, acuity, phenomena, sufficiently,
# Nearest to experience: ascended, neuroscience, derisively, pinball, strived, life, reality, our,
# Nearest to applications: task, keynesians, desk, cnc, lapsed, ported, deanna, materials,
# Nearest to joseph: duce, boyle, blessing, gaule, peter, consonance, relativist, leonid,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9864 0.4513 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0456 0.4140 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9486 0.4488 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0401 0.4573 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0192 0.4621 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9438 0.4357 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9878 0.4054 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9979 0.4000 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9931 0.4156 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0016 0.4105 sec/batch
# Nearest to new: york, chartered, oxford, press, surfing, expositions, hebrides, completed,
# Nearest to have: though, sayings, callisthenes, fallacies, sonia, there, decentralized, enjoy,
# Nearest to two: four, three, zero, five, one, nine, seven, six,
# Nearest to th: onward, early, rd, transl, markkaa, graphemes, afc, six,
# Nearest to years: year, vong, zero, eight, four, infant, age, fertility,
# Nearest to some: isabelle, licence, shudo, tone, efficacy, grasp, ours, terseness,
# Nearest to however: accelerated, tetum, relegated, theirs, territory, single, tariff, inhibitors,
# Nearest to when: it, chime, brosnan, inappropriately, to, incubation, labia, teos,
# Nearest to creation: darlington, ninja, rentals, bang, maintains, concepts, legalism, spinoza,
# Nearest to shows: infidelity, tab, hoffman, vanuatu, graph, avengers, clockwise, rapport,
# Nearest to derived: etymology, production, expectancies, family, nonterminal, name, monmouth, hanafi,
# Nearest to issue: karl, refusing, jong, appalachia, crick, plies, sdf, novell,
# Nearest to scale: ellipses, accessible, nanotechnology, solstice, acuity, intuitive, phenomena, sufficiently,
# Nearest to experience: ascended, reality, neuroscience, pinball, completeness, our, derisively, strived,
# Nearest to applications: cnc, task, keynesians, desk, lapsed, deanna, ported, engineers,
# Nearest to joseph: boyle, duce, gaule, peter, leonid, blessing, poet, consonance,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9938 0.4263 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0100 0.4087 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-b1d3869cd0d6> in <module>()
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# C:\ProgramData\Anaconda3\envs\dlnd\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\ProgramData\Anaconda3\envs\dlnd\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# C:\ProgramData\Anaconda3\envs\dlnd\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\ProgramData\Anaconda3\envs\dlnd\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# C:\ProgramData\Anaconda3\envs\dlnd\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
